# %%
import os
from collections import Counter
from PIL import Image
from tqdm import tqdm

def analyze_all_datasets(base_path, top_n=10):
    valid_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.webp', '.tiff')
    global_sizes = []
    
    # Buscar todas las carpetas 'train' dentro de los directorios .coco
    # O simplemente cualquier subcarpeta que contenga imágenes
    subdirs = [f.path for f in os.scandir(base_path) if f.is_dir() and not f.name.startswith('.')]
    
    print(f"Se encontraron {len(subdirs)} subdirectorios potenciales para analizar.\n")
    
    for subdir in subdirs:
        # Apuntar a la carpeta 'train' si existe, si no, analizar el subdirectorio raíz
        target_dir = os.path.join(subdir, 'train')
        if not os.path.exists(target_dir):
            target_dir = subdir # Por si alguna carpeta como '15' tiene imágenes directo
            
        # Listar imágenes válidas
        try:
            files = [f for f in os.listdir(target_dir) if f.lower().endswith(valid_extensions)]
        except Exception:
            continue # Si no se puede acceder o no es un directorio válido
            
        if not files:
            continue

        print(f"Analizando subdataset: {os.path.basename(subdir)} ({len(files)} imágenes)...")
        local_sizes = []

        for filename in tqdm(files, desc=os.path.basename(subdir)[:20]):
            img_path = os.path.join(target_dir, filename)
            try:
                with Image.open(img_path) as img:
                    # (width, height)
                    local_sizes.append(img.size)
            except Exception as e:
                print(f" -> Error en {filename}: {e}")

        # Añadir al acumulador global
        global_sizes.extend(local_sizes)
        
        # Mostrar top local
        local_counts = Counter(local_sizes)
        print(f"-> Tamaños más comunes en {os.path.basename(subdir)}:")
        for size, count in local_counts.most_common(3):
            print(f"   {str(size):<15} : {count} imágenes")
        print("-" * 60)

    # --- Resumen Global ---
    if not global_sizes:
        print("No se encontraron imágenes válidas en ningún subdirectorio.")
        return

    global_counts = Counter(global_sizes)
    most_common_global = global_counts.most_common(top_n)

    print("\n" + "="*20 + " RESUMEN GLOBAL DEL DATASET " + "="*20)
    print(f"Total de imágenes analizadas: {len(global_sizes)}")
    print(f"Total de resoluciones distintas: {len(global_counts)}")
    print("\n--- Top Tamaños Globales ---")
    print(f"{'Ranking':<10} | {'Resolución (W x H)':<20} | {'Cantidad'} | {'Porcentaje'}")
    print("-" * 65)
    
    for i, (size, count) in enumerate(most_common_global, 1):
        percentage = (count / len(global_sizes)) * 100
        print(f"{i:<10} | {str(size):<20} | {count:<13} | {percentage:.2f}%")

if __name__ == "__main__":
    # Tu nueva ruta en la partición montada de Linux
    ruta_dataset = '/media/john/Windows-SSD/Dataset_Cacaos'
    analyze_all_datasets(ruta_dataset)
# Out:
# Se encontraron 9 subdirectorios potenciales para analizar.
#
# Analizando subdataset: 312_-.coco (312 imágenes)...
# 312_-.coco: 100%|██████████| 312/312 [00:00<00:00, 12490.79it/s]
# -> Tamaños más comunes en 312_-.coco:
#    (3120, 4160)    : 308 imágenes
#    (4160, 3120)    : 2 imágenes
#    (1200, 1600)    : 1 imágenes
# ------------------------------------------------------------
# Analizando subdataset: IMM_-.coco (872 imágenes)...
# IMM_-.coco: 100%|██████████| 872/872 [00:00<00:00, 20099.98it/s]
# -> Tamaños más comunes en IMM_-.coco:
#    (4000, 3000)    : 312 imágenes
#    (4284, 5712)    : 235 imágenes
#    (4000, 5333)    : 128 imágenes
# ------------------------------------------------------------
# Analizando subdataset: nenesVert_-.coco (633 imágenes)...
# nenesVert_-.coco: 100%|██████████| 633/633 [00:00<00:00, 21074.90it/s]
# -> Tamaños más comunes en nenesVert_-.coco:
#    (720, 1280)     : 321 imágenes
#    (3120, 4160)    : 308 imágenes
#    (4160, 3120)    : 2 imágenes
# ------------------------------------------------------------
# Analizando subdataset: nesnes_horiz --.coco (990 imágenes)...
# nesnes_horiz --.coco: 100%|██████████| 990/990 [00:00<00:00, 38867.41it/s]
# -> Tamaños más comunes en nesnes_horiz --.coco:
#    (720, 422)      : 990 imágenes
# ------------------------------------------------------------
# Analizando subdataset: rotsinHe --.coco (1804 imágenes)...
# rotsinHe --.coco: 100%|██████████| 1804/1804 [00:00<00:00, 40022.03it/s]
# -> Tamaños más comunes en rotsinHe --.coco:
#    (1080, 1080)    : 1781 imágenes
#    (2160, 2160)    : 23 imágenes
# ------------------------------------------------------------
# Analizando subdataset: San_-.coco (501 imágenes)...
# San_-.coco: 100%|██████████| 501/501 [00:00<00:00, 21008.21it/s]
# -> Tamaños más comunes en San_-.coco:
#    (505, 505)      : 461 imágenes
#    (1840, 4080)    : 31 imágenes
#    (1009, 1009)    : 9 imágenes
# ------------------------------------------------------------
# Analizando subdataset: trainhoriz.coco (2059 imágenes)...
# trainhoriz.coco: 100%|██████████| 2059/2059 [00:00<00:00, 40906.96it/s]
# -> Tamaños más comunes en trainhoriz.coco:
#    (1280, 720)     : 2007 imágenes
#    (1920, 1080)    : 52 imágenes
# ------------------------------------------------------------
# Analizando subdataset: train_vert --.coco (2012 imágenes)...
# train_vert --.coco: 100%|██████████| 2012/2012 [00:00<00:00, 37753.39it/s]
# -> Tamaños más comunes en train_vert --.coco:
#    (409, 720)      : 2012 imágenes
# ------------------------------------------------------------
# Analizando subdataset: valnes --.coco (940 imágenes)...
# valnes --.coco: 100%|██████████| 940/940 [00:00<00:00, 40174.92it/s]
# -> Tamaños más comunes en valnes --.coco:
#    (720, 1280)     : 940 imágenes
# ------------------------------------------------------------
#
# ==================== RESUMEN GLOBAL DEL DATASET ====================
# Total de imágenes analizadas: 10123
# Total de resoluciones distintas: 21
#
# --- Top Tamaños Globales ---
# Ranking    | Resolución (W x H)   | Cantidad | Porcentaje
# -----------------------------------------------------------------
# 1          | (409, 720)           | 2012          | 19.88%
# 2          | (1280, 720)          | 2007          | 19.83%
# 3          | (1080, 1080)         | 1781          | 17.59%
# 4          | (720, 1280)          | 1261          | 12.46%
# 5          | (720, 422)           | 990           | 9.78%
# 6          | (3120, 4160)         | 616           | 6.09%
# 7          | (505, 505)           | 461           | 4.55%
# 8          | (4000, 3000)         | 312           | 3.08%
# 9          | (4284, 5712)         | 235           | 2.32%
# 10         | (4000, 5333)         | 128           | 1.26%

# %%
import os
import math
from collections import Counter
from PIL import Image
from tqdm import tqdm

def get_approx_ratio(w, h):
    ratio = w / h
    # Buscar relaciones de aspecto estándares comunes
    standards = [
        (1.0, "1:1 (Cuadrada)"),
        (16/9, "16:9 (Horizontal)"),
        (9/16, "9:16 (Vertical)"),
        (4/3, "4:3 (Horizontal)"),
        (3/4, "3:4 (Vertical)"),
    ]
    for val, name in standards:
        if abs(ratio - val) < 0.03:
            return name
    
    # Si no es estándar, simplificar la fracción básica
    gcd = math.gcd(w, h)
    return f"{w//gcd}:{h//gcd} (Personalizada)"

def analyze_aspect_ratios(base_path):
    valid_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.webp', '.tiff')
    ratios_global = []
    total_files = 0

    subdirs = [f.path for f in os.scandir(base_path) if f.is_dir() and not f.name.startswith('.')]
    
    for subdir in subdirs:
        target_dir = os.path.join(subdir, 'train')
        if not os.path.exists(target_dir):
            target_dir = subdir
            
        try:
            files = [f for f in os.listdir(target_dir) if f.lower().endswith(valid_extensions)]
        except Exception:
            continue
            
        if not files:
            continue

        total_files += len(files)
        for filename in tqdm(files, desc=f"Procesando {os.path.basename(subdir)[:15]}"):
            img_path = os.path.join(target_dir, filename)
            try:
                with Image.open(img_path) as img:
                    w, h = img.size
                    ratio_label = get_approx_ratio(w, h)
                    ratios_global.append(ratio_label)
            except Exception:
                pass

    if not ratios_global:
        print("No se encontraron imágenes.")
        return

    counts = Counter(ratios_global)
    print("\n" + "="*20 + " DISTRIBUCIÓN DE RELACIONES DE ASPECTO " + "="*20)
    print(f"{'Relación de Aspecto':<30} | {'Cantidad':<10} | {'Porcentaje'}")
    print("-" * 60)
    for ratio, count in counts.most_common():
        pct = (count / len(ratios_global)) * 100
        print(f"{ratio:<30} | {count:<10} | {pct:.2f}%")

if __name__ == "__main__":
    ruta_dataset = '/media/john/Windows-SSD/Dataset_Cacaos'
    analyze_aspect_ratios(ruta_dataset)
# Out:
# Procesando 312_-.coco:   0%|          | 0/312 [00:00<?, ?it/s]
# Procesando 312_-.coco: 100%|██████████| 312/312 [00:00<00:00, 10594.51it/s]
# Procesando IMM_-.coco: 100%|██████████| 872/872 [00:00<00:00, 19409.93it/s]
# Procesando nenesVert_-.coc: 100%|██████████| 633/633 [00:00<00:00, 20550.45it/s]
# Procesando nesnes_horiz --: 100%|██████████| 990/990 [00:00<00:00, 39944.98it/s]
# Procesando rotsinHe --.coc: 100%|██████████| 1804/1804 [00:00<00:00, 39472.10it/s]
# Procesando San_-.coco: 100%|██████████| 501/501 [00:00<00:00, 38800.29it/s]
# Procesando trainhoriz.coco: 100%|██████████| 2059/2059 [00:00<00:00, 40483.93it/s]
# Procesando train_vert --.c: 100%|██████████| 2012/2012 [00:00<00:00, 39833.38it/s]
# Procesando valnes --.coco: 100%|██████████| 940/940 [00:00<00:00, 39812.64it/s]
# ==================== DISTRIBUCIÓN DE RELACIONES DE ASPECTO ====================
# Relación de Aspecto            | Cantidad   | Porcentaje
# ------------------------------------------------------------
# 9:16 (Vertical)                | 3275       | 32.35%
# 1:1 (Cuadrada)                 | 2274       | 22.46%
# 16:9 (Horizontal)              | 2059       | 20.34%
# 3:4 (Vertical)                 | 1162       | 11.48%
# 360:211 (Personalizada)        | 990        | 9.78%
# 4:3 (Horizontal)               | 316        | 3.12%
# 23:51 (Personalizada)          | 31         | 0.31%
# 32:9 (Personalizada)           | 16         | 0.16%
